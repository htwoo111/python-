# %%
import requests
import json


class JDSpider(object):
    def __init__(self):
        self.url_temp = "https://sclub.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98vv20995&productId=100001550349&score=0&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1"
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36",
            "Referer": "https://item.jd.com/100001550349.html"
        }
        self.proxies = {"https": "https:61.128.208.94:3128"}

        
    def parse_url(self, url):
        print(url)
        """发送请求，获取数据"""
        try:
            r = requests.get(url, headers=self.headers, proxies=self.proxies)
            return r.text
        except:
            print("爬取失败")
            
            
    def get_comment_list(self, html_str):
        html_str2 = html_str[27:-2]
        ret_dict = json.loads(html_str2)
        return ret_dict["comments"]
        
        
    def save_data(self, comment_list):
        with open("../crawl_file/016.jdSpider.txt", 'a', encoding='utf-8') as f:
            for comment in comment_list:
                f.write(json.dumps(comment['content'], ensure_ascii=False))
                f.write('\n')
            print('保存成功')
        
        
    def run(self):
        """运行主程序"""
        # 1.获取start_url
        current_page = 67
        while True:
            url = self.url_temp.format(current_page)
            # 2.发送请求，获取数据
            html_str = self.parse_url(url)
            # 3.提取数据
            comment_list = self.get_comment_list(html_str)
            # 4.保存
            self.save_data(comment_list)
            if (len(comment_list)<10) or (current_page==1000):
                break
            # 5.构造下一个url
            current_page += 1
    
    
if __name__ == "__main__":
    jd_spider = JDSpider()
    jd_spider.run()
#     print(comment_list)
# Out:
# https://sclub.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98vv20995&productId=100001550349&score=0&sortType=5&page=67&pageSize=10&isShadowSku=0&rid=0&fold=1
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-60-0585c67e1be8> in <module>
#      57 if __name__ == "__main__":
#      58     jd_spider = JDSpider()
# ---> 59     jd_spider.run()
#      60 #     print(comment_list)
#
# <ipython-input-60-0585c67e1be8> in run(self)
#      46             html_str = self.parse_url(url)
#      47             # 3.提取数据
# ---> 48             comment_list = self.get_comment_list(html_str)
#      49             # 4.保存
#      50             self.save_data(comment_list)
#
# <ipython-input-60-0585c67e1be8> in get_comment_list(self, html_str)
#      25     def get_comment_list(self, html_str):
#      26         html_str2 = html_str[27:-2]
# ...

# %%
import requests
import json


class JDSpider(object):
    def __init__(self):
        self.url_temp = "https://sclub.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98vv20995&productId=100001550349&score=0&sortType=5&page={}&pageSize=10&isShadowSku=0&rid=0&fold=1"
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36",
            "Referer": "https://item.jd.com/100001550349.html"
        }
        self.proxies = {"https": "https:61.128.208.94:3128"}

        
    def parse_url(self, url):
        print(url)
        """发送请求，获取数据"""
        try:
            r = requests.get(url, headers=self.headers, proxies=self.proxies)
            return r.text
        except:
            print("爬取失败")
            
            
    def get_comment_list(self, html_str):
        html_str2 = html_str[27:-2]
        ret_dict = json.loads(html_str2)
        return ret_dict["comments"]
        
        
    def save_data(self, comment_list):
        with open("../crawl_file/016.jdSpider.txt", 'a', encoding='utf-8') as f:
            for comment in comment_list:
                f.write(json.dumps(comment['content'], ensure_ascii=False))
                f.write('\n')
            print('保存成功')
        
        
    def run(self):
        """运行主程序"""
        # 1.获取start_url
        current_page = 67
        while True:
            url = self.url_temp.format(current_page)
            # 2.发送请求，获取数据
            html_str = self.parse_url(url)
            if html_str is None:
                continue
            # 3.提取数据
            comment_list = self.get_comment_list(html_str)
            # 4.保存
            self.save_data(comment_list)
            if (len(comment_list)<10) or (current_page==1000):
                break
            # 5.构造下一个url
            current_page += 1
    
    
if __name__ == "__main__":
    jd_spider = JDSpider()
    jd_spider.run()
#     print(comment_list)
# Out:
# https://sclub.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98vv20995&productId=100001550349&score=0&sortType=5&page=67&pageSize=10&isShadowSku=0&rid=0&fold=1
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-66-2266c7537732> in <module>
#      59 if __name__ == "__main__":
#      60     jd_spider = JDSpider()
# ---> 61     jd_spider.run()
#      62 #     print(comment_list)
#
# <ipython-input-66-2266c7537732> in run(self)
#      48                 continue
#      49             # 3.提取数据
# ---> 50             comment_list = self.get_comment_list(html_str)
#      51             # 4.保存
#      52             self.save_data(comment_list)
#
# <ipython-input-66-2266c7537732> in get_comment_list(self, html_str)
#      25     def get_comment_list(self, html_str):
#      26         html_str2 = html_str[27:-2]
# ...
