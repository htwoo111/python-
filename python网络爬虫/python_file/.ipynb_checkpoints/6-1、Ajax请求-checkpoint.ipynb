# %%
# 项目演习
# 爬取微博某博主前10的内容

from urllib.parse import urlencode
import requests
from pyquery import PyQuery as pq
from pymongo import MongoClient
def mongo_weibo():
    client = MongoClient()
    db = client['weibo']
    collection = db['weibo']

    return collection


base_url = "https://m.weibo.cn/api/container/getIndex?"
headers = {
    "Referer": "https://m.weibo.cn/u/2830678474",
    "User-Agent":
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36",
    "X-Requested-With": "XMLHttpRequest"
}


def get_page(page):
    params = {
        'type': 'uid',
        'value': '2830678474',
        'containerid': '1076032830678474',
        'page': page
    }

    url = base_url + urlencode(params)
    try:
        response = requests.get(url, headers)
        if response.status_code == 200:
            return response.json()
    except requests.ConnectionError as e:
        print("Error is ", e.args)


def parse_page(json):
    if json:
        items = json.get('data').get('cards')
        for item in items:
            item = item.get('mblog')
            weibo = {}
            weibo['id'] = item.get('id')
            weibo['text'] = pq(item.get('text')).text()
            weibo['attitudes'] = item.get('attitudes_count')
            weibo['comments'] = item.get('comments_count')
            weibo['reposts'] = item.get('reposts_count')
            yield weibo

def save_to_mongo(result):
    collection.insert_one(result)
    print('保存成功')

# %%
if __name__ == "__main__":
    collection = mongo_weibo()
    for page in range(1, 11):
        json = get_page(page)
        results = parse_page(json)
        for result in results:
            print(result)
            save_to_mongo(result)
# Out:
# {'id': '4419073695362369', 'text': '', 'attitudes': 8, 'comments': 0, 'reposts': 9}
# 保存成功
# {'id': '4419018955543367', 'text': '', 'attitudes': 13, 'comments': 11, 'reposts': 2}
# 保存成功
# {'id': '4418733068394094', 'text': '啊啊啊啊啊啊啊！！我老婆给我买的四驱车！！！！\n老婆我爱你！！！', 'attitudes': 17, 'comments': 6, 'reposts': 1}
# 保存成功
# {'id': '4418413679863350', 'text': '一天开了五个会，写代码都是在会和会的缝隙写，导致今天的东西现在才写完，这么多会意义何在呢。\n感到最愧对的是我老婆，工作没做完，都不能好好陪老婆，最后终于写完了，老婆已经睡了。', 'attitudes': 10, 'comments': 3, 'reposts': 0}
# 保存成功
# {'id': '4417499816303949', 'text': '', 'attitudes': 2, 'comments': 1, 'reposts': 7}
# 保存成功
# {'id': '4417499623972281', 'text': '小冰生日快乐！', 'attitudes': 2, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4417076179338410', 'text': '好看', 'attitudes': 3, 'comments': 1, 'reposts': 5}
# 保存成功
# {'id': '4416848646749408', 'text': '我们都是大画家！', 'attitudes': 9, 'comments': 3, 'reposts': 0}
# 保存成功
# {'id': '4416716203311404', 'text': '我老婆绝了！\n我终于时隔多年吃到了童年的味道！\n京酱肉丝面！', 'attitudes': 9, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4416348975114576', 'text': '', 'attitudes': 3, 'comments': 0, 'reposts': 1}
# 保存成功
# {'id': '4416347389426517', 'text': '什么叫眼比天高呢？\n我老婆每天都喷人家外面的松饼那么点就卖四十块钱一盘，今天她自己做了一下以后已经心甘情愿为外面的松饼掏钱了：太鸡儿难了。\n不过，经过我的完美的摆盘设计，成功实现了颜比天高。\n我可真是太棒了！', 'attitudes': 4, 'comments': 2, 'reposts': 0}
# 保存成功
# {'id': '4414764329825592', 'text': '爬虫智能解析库 Readability 和 Newspaper 的用法网页链接', 'attitudes': 13, 'comments': 0, 'reposts': 7}
# 保存成功
# {'id': '4414589711949736', 'text': '爱爱爱爱老婆！', 'attitudes': 2, 'comments': 9, 'reposts': 2}
# 保存成功
# {'id': '4414382547079274', 'text': '回复@武汉传奇少年://@武汉传奇少年:回复@紫金县城最亮的zai:李楠关上了中国篮球的大门，周琦不放心，顺手把窗关上了。郭艾伦检查了一遍还上了两把锁，易建联想出去透透气，被他们按住了。', 'attitudes': 5, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4414381494528151', 'text': '', 'attitudes': 2, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4414376566528213', 'text': '回复@_刘三斤_:不，是因为我老婆。//@_刘三斤_:难道工作了真会变胖吗？', 'attitudes': 0, 'comments': 2, 'reposts': 0}
# 保存成功
# {'id': '4414376159688672', 'text': '比赛结束了，我让我老婆猜周琦今天得了多少分，今天男篮生死战，还给了个参考今天易建联 27 分。\n我老婆猜了都有 8 分！\n我摇头说不对，我老婆就慢慢往下减分，减到 3 分的时候我老婆都迟疑了。\n：不会两分吧？\n：没错，就两分。\n生死战2分4板5犯离场 这就是我们曾经期待的下任旗手？\n@周琦_9 ...全文', 'attitudes': 38, 'comments': 4, 'reposts': 3}
# 保存成功
# {'id': '4414368559360716', 'text': '好久没用，打开了我的 keep，嗯？\n我之前 57kg？\n我是不是该修改下体重了？\n好的，算了一下，默默改成了 68kg。', 'attitudes': 6, 'comments': 9, 'reposts': 1}
# 保存成功
# {'id': '4414002752832725', 'text': '老婆带我买到了一双 allbirds 鞋，据说这是湾区优秀的程序员特别喜欢的款，我心想我也是一名优秀的程序员，那我也要买！\n开玩笑哈哈，主要是因为我上脚之后感觉特别舒服，料子特别软，还超级轻！\n我爱了，这可能是我穿过的最舒服的鞋！\n以后我要天天穿！ ...全文', 'attitudes': 7, 'comments': 4, 'reposts': 0}
# 保存成功
# {'id': '4414000966167273', 'text': '在三里屯逛苹果店，看到了一个十岁左右的小男孩为了测试 CPU 性能写了一段 Python，还用的多线程 threading，虽然他运行的时候出现了一些编译错误，看了下是缩进问题，但整个撸代码的过程非常流畅。日，感到了危机。 北京·三里屯VILLAGE南区 崔庆才丨静觅的微博视频', 'attitudes': 54, 'comments': 6, 'reposts': 24}
# 保存成功
# {'id': '4413952756650845', 'text': '我老婆可真好看啊！ 北京·2019北京世园会', 'attitudes': 15, 'comments': 7, 'reposts': 0}
# 保存成功
# {'id': '4413300832139570', 'text': '我是各种连续奇怪的符号//@GitHubDaily://@蚁工厂:"1111" "2222"……//@Style2Paints: //@爱可可-爱生活 :确定不是“here”……“eree”……“reee”……“eeee” ？ //@路遇温姑娘 : 我是“here”…“hereeeeeeee”', 'attitudes': 5, 'comments': 2, 'reposts': 4}
# 保存成功
# {'id': '4413300194240642', 'text': '//@GitHubDaily:哈哈哈哈哈//@Easy:不要这样 哈哈哈 //@霜叶: 这谁统计的？不会是钓鱼吧？//@月刊勇者KuMa君: 牛逼//@小智在那美克星:哈哈哈哈哈好真实//@Aby55:哈哈哈哈哈哈哈哈哈哈哈我笑傻了', 'attitudes': 3, 'comments': 0, 'reposts': 3}
# 保存成功
# {'id': '4413297162264707', 'text': '我一个月涨了七斤，实打实的。\n现在裤也穿不上了，腿也不细了，下巴也没了。\n他妈的我老婆怎么找的吃的都这么好吃啊！', 'attitudes': 7, 'comments': 3, 'reposts': 0}
# 保存成功
# {'id': '4413153088087277', 'text': '好的！//@长泽牙妹:@崔庆才丨静觅 记着点！！！给孩子送去下棋！！！', 'attitudes': 1, 'comments': 0, 'reposts': 1}
# 保存成功
# {'id': '4412950482172893', 'text': '//@GitHubDaily:这个挺有意思//@没有我找不到的电子书: 这个好', 'attitudes': 8, 'comments': 0, 'reposts': 36}
# 保存成功
# {'id': '4412223785300789', 'text': '为什么周琦会犯这么低级的失误呢？因为在 NBA 连个发边线球的机会都没有，只能发啤酒饮料矿泉水。😂 @周琦_9', 'attitudes': 5, 'comments': 2, 'reposts': 0}
# 保存成功
# {'id': '4412197964805047', 'text': '//@耳帝:还未听过原版的可以听下：davidfnck的微博视频 原歌词更有味道//@祝佳音:最打动我的是开头蹩脚的粤语。在我高中时代，粤语歌很流行，同学们都会照虎画猫地唱几句粤语，肯定不标准，但这首歌把这不标准表达得特别标准。这歌什么时候让我想起东北，其实有粤语的第一', 'attitudes': 1, 'comments': 0, 'reposts': 2}
# 保存成功
# {'id': '4412135310209834', 'text': '快来看！', 'attitudes': 1, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4411510036218292', 'text': '//@GitHubDaily://@蚁工厂://@互联网翻车指南:静观其变，ZAO用户协议应该会改的吧，看看法律工作者的说法。', 'attitudes': 3, 'comments': 0, 'reposts': 1}
# 保存成功
# {'id': '4411502460941932', 'text': '谈谈 Zao 这个软件这个软件真不简单', 'attitudes': 19, 'comments': 0, 'reposts': 25}
# 保存成功
# {'id': '4411459410672596', 'text': '我老婆也太能吃了吧。\n满满的一盆煲仔饭，我就吃了几口，她哼哧哼哧吃完了。我当时还跟老婆打赌，你要全吃完了我给你一百块钱，结果... 北京·朝外SOHO', 'attitudes': 7, 'comments': 5, 'reposts': 0}
# 保存成功
# {'id': '4411067653979658', 'text': '真是饿坏了什么都想吃。 北京·大运村公寓', 'attitudes': 2, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4410755736424834', 'text': '不，我要我的福报 996！//@韦字只念第二声:福爆呢！！我们年轻人需要福爆！！', 'attitudes': 4, 'comments': 0, 'reposts': 1}
# 保存成功
# {'id': '4409651745610530', 'text': '闯了两个红灯了。', 'attitudes': 2, 'comments': 5, 'reposts': 0}
# 保存成功
# {'id': '4409651506186207', 'text': '今晚打的这个车司机开车太猛了，起步是窜出去的，刹车是急刹车，拐弯不踩油门的，还压时间闯了个红灯。 北京', 'attitudes': 0, 'comments': 2, 'reposts': 1}
# 保存成功
# {'id': '4409609081226450', 'text': '我老婆太牛逼了！！！\n我们从塞尔维亚回来的卡塔尔航空给我们延误了行李，我本想没太有希望找回赔偿了，但我老婆找到了卡塔尔客户关怀部，然后又转到了北京机场团队，最后获得了 200 美刀的赔偿！！！\n老婆牛逼！！！！\n顺便晒一下新的桌面嘿嘿！我老婆也太厉害了吧！ ...全文', 'attitudes': 16, 'comments': 8, 'reposts': 0}
# 保存成功
# {'id': '4409024671559957', 'text': '//@长泽牙妹:才哥从刚谈恋爱的时候比我瘦十二斤 一直被我养到现在比我胖七斤也不知道你们看没看过cctv财经频道 “大学生养猪致富”//@长泽牙妹:恭喜崔哥胖到135', 'attitudes': 1, 'comments': 4, 'reposts': 0}
# 保存成功
# {'id': '4408965049702755', 'text': '我回来啦！还是我大北京好啊！满满的亲切感！ 北京·首都机场T3航站楼', 'attitudes': 13, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4408860301096678', 'text': '卡塔尔航空上提供了 WiFi，但是它只能连一小时，用更多的时间就需要购买。经过我的研究，它其实就是用了 Cookies 来记录和分辨每个设备的，所以只需要浏览器端清理下 Cookies 就可以重新连接了。', 'attitudes': 24, 'comments': 18, 'reposts': 1}
# 保存成功
# {'id': '4408850168111863', 'text': '起飞了！！！回国！！！！ 卡塔尔', 'attitudes': 7, 'comments': 2, 'reposts': 0}
# 保存成功
# {'id': '4408670286434737', 'text': '回国来多哈转机，不得不说卡塔尔这地方是真牛逼啊！有钱就是不一样！来瓦齐夫市场看了看，还住到了万豪，老婆牛逼！ 卡塔尔·多哈', 'attitudes': 11, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4408470080486463', 'text': '和老婆的塞尔维亚&波黑之行圆满结束，旅行前后最大的区别是什么呢？\n答：胖若两人。 塞尔维亚', 'attitudes': 26, 'comments': 13, 'reposts': 0}
# 保存成功
# {'id': '4408305155506478', 'text': '回贝尔格莱德啦，这个肉是真的带劲啊！\n足足 1kg 肉，吃得我和我老婆生无可恋。\n不过确实好吃。 塞尔维亚·贝尔格莱德', 'attitudes': 7, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4408261941728820', 'text': '曝光！', 'attitudes': 0, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4408100884548526', 'text': '@长泽牙妹', 'attitudes': 0, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4407899427952367', 'text': '萨拉热窝的日落。 波黑·萨拉热窝', 'attitudes': 6, 'comments': 1, 'reposts': 1}
# 保存成功
# {'id': '4407866549045215', 'text': '转发微博', 'attitudes': 0, 'comments': 0, 'reposts': 1}
# 保存成功
# {'id': '4407843354066469', 'text': '回复@风尘丶刻画你的脸:看了俩小时波斯尼亚语无字幕版愤怒的小鸟，全程脑补的，我太难了。//@风尘丶刻画你的脸:哇哇哇，国外的影院，电影说啥听得懂不', 'attitudes': 0, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4407818872237584', 'text': '这儿的爆米花居然是咸的？ 波黑', 'attitudes': 3, 'comments': 4, 'reposts': 1}
# 保存成功
# {'id': '4407640576862723', 'text': '妈的激动得有点睡不着觉…… 波黑·萨拉热窝', 'attitudes': 5, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4407639905417609', 'text': '有时候一个小小的灵感就能引起巨变，今天尝试了下，希望明天能有个好结果！\n成功的话，就能起飞了！ 波黑·萨拉热窝', 'attitudes': 10, 'comments': 0, 'reposts': 1}
# 保存成功
# {'id': '4407547089939170', 'text': '转发微博', 'attitudes': 2, 'comments': 1, 'reposts': 1}
# 保存成功
# {'id': '4407546733439309', 'text': '😂😂//@精神病院门没关好我跑出来了:哈哈哈哈哈哈哈//@休闲璐:给我笑饿了//@然后下面就没了:沙雕哈哈哈哈哈哈哈哈//@M大王叫我来巡山:干嘛啊哈哈哈哈哈哈哈哈哈，憨憨//@胭脂牌锦鲤: 哈哈哈哈哈哈哈哈什么毛病//@秧苗成长日记:给我笑失眠了', 'attitudes': 3, 'comments': 2, 'reposts': 4}
# 保存成功
# {'id': '4407492836329772', 'text': '萨拉热窝还真是热窝啊。', 'attitudes': 3, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4407380625957152', 'text': '', 'attitudes': 5, 'comments': 1, 'reposts': 11}
# 保存成功
# {'id': '4407096869078102', 'text': '这六连中我可以吹一年！ 塞尔维亚 崔庆才丨静觅的微博视频', 'attitudes': 17, 'comments': 11, 'reposts': 0}
# 保存成功
# {'id': '4406698544366420', 'text': '我老婆真是好绝一女的。 塞尔维亚·诺维萨德', 'attitudes': 18, 'comments': 4, 'reposts': 0}
# 保存成功
# {'id': '4406441185694680', 'text': '卧槽！范迪塞尔！！！ 塞尔维亚·诺维萨德', 'attitudes': 17, 'comments': 9, 'reposts': 2}
# 保存成功
# {'id': '4406438287514490', 'text': '这些人打球还真的像约老湿啊，灵活死胖子。 塞尔维亚·诺维萨德 崔庆才丨静觅的微博视频', 'attitudes': 8, 'comments': 5, 'reposts': 0}
# 保存成功
# {'id': '4406390489414678', 'text': '苏博蒂察是个好地方，早餐这顿太满足，这俩一共才四十多块钱了，另外早餐期间还意外收获了老婆拍我的一张重新捡回颜值的照片。\n说正事，这个帕丽奇湖太好看了，不过再好看也比不上我老婆好看！ @长泽牙妹\n好的，现在上车车，去往下个目的地，诺维萨德！ 塞尔维亚·苏博蒂察', 'attitudes': 9, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4406330615498945', 'text': '塞尔维亚 崔庆才丨静觅的微博视频', 'attitudes': 4, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4406301481776743', 'text': '查看图片', 'attitudes': 3, 'comments': 10, 'reposts': 0}
# 保存成功
# {'id': '4406094786722831', 'text': '依然日常看不懂菜单，还好服务员都会说英文。 塞尔维亚', 'attitudes': 2, 'comments': 2, 'reposts': 0}
# 保存成功
# {'id': '4406081666836359', 'text': '可爱的塞尔维亚人民，像不像晚上乡里乡亲们聚在村头看表演的感觉呢？ 塞尔维亚 崔庆才丨静觅的微博视频', 'attitudes': 2, 'comments': 3, 'reposts': 0}
# 保存成功
# {'id': '4406034863305509', 'text': '', 'attitudes': 1, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4406031951719230', 'text': '马克', 'attitudes': 2, 'comments': 0, 'reposts': 1}
# 保存成功
# {'id': '4406018244844489', 'text': '一个字都不认识啊，但是学好英语走遍天下还真是有道理啊！ 塞尔维亚·贝尔格莱德', 'attitudes': 0, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4405996338448061', 'text': '这小风吹着是真舒服啊！下午决定就在这个小亭子撸代码了！ 塞尔维亚·贝尔格莱德', 'attitudes': 19, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4405714837195203', 'text': '', 'attitudes': 5, 'comments': 0, 'reposts': 2}
# 保存成功
# {'id': '4405713528732762', 'text': '恭喜小冰又向前迈了一步，这次我做的功能也上发布会啦哈哈！开心！', 'attitudes': 18, 'comments': 2, 'reposts': 2}
# 保存成功
# {'id': '4405711448389300', 'text': '今天老婆找了一个贝尔格莱德的当地居民给我们当向导，带我们去市场买了菜，然后带逛和介绍各种建筑和景点，最后来到他家做客，给我们准备了各种吃的，不得不说那个猪排是真的一绝了！然而可惜忘了拍照了，真的就是他们特别热情好客，生活节奏也慢。\n嗯，学会享受生活。 塞尔维亚·贝尔格莱德', 'attitudes': 7, 'comments': 4, 'reposts': 0}
# 保存成功
# {'id': '4405688740687352', 'text': '日常秀老婆！ 塞尔维亚·贝尔格莱德', 'attitudes': 18, 'comments': 12, 'reposts': 0}
# 保存成功
# {'id': '4405527767470222', 'text': '试试', 'attitudes': 1, 'comments': 2, 'reposts': 7}
# 保存成功
# {'id': '4405367691297105', 'text': '之前听说别人的裤子穿不上了，腰带紧了，都是距离我很遥远的事情，但是今天我终于体会到了这种痛。\n我本来带了两条裤子来塞尔维亚，结果今天换衣服的时候发现我都已经穿不上了，任凭我怎么收肚子，那个腰扣都系不上了。\n绝望之下，我老婆就和我出来买裤子。我之前都穿 29 码的裤子的，今天我来试裤子， ...全文', 'attitudes': 4, 'comments': 13, 'reposts': 0}
# 保存成功
# {'id': '4405345528667554', 'text': '塞尔维亚人民还是很友好的，刚才我走在大街上，有一个小孩子迎面朝我走来，然后直接对我说了一句你好，还朝我摆了摆手。然后我立马也说了一句你好，然后我们就开心的笑了起来，哈哈哈哈。 塞尔维亚', 'attitudes': 7, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4405263047828469', 'text': 'Airbnb 老板开车接我们，还给我们推荐了一个餐厅，把里面最贵的吃的点了，发现只有六十块人民币，嫩的一批，老婆牛逼！ 塞尔维亚·贝尔格莱德', 'attitudes': 11, 'comments': 2, 'reposts': 0}
# 保存成功
# {'id': '4405254810998248', 'text': '我 jio 得可以！', 'attitudes': 2, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4405232685968203', 'text': '成功抵达！ 塞尔维亚·贝尔格莱德尼古拉特斯拉机场 Nikola Tesla Airport', 'attitudes': 5, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4405148359079878', 'text': '这个卡塔尔航空是真牛逼啊，飞机餐还是相当可以的，还有我最喜欢的黄桃畅轻！\n到了多哈转机，一直没觉得多哈有多热，一直到坐摆渡车，我的 🐴 鸭！\n短暂一小时停留，又要飞去贝尔格莱德啦！ 卡塔尔·哈马德国际机场', 'attitudes': 8, 'comments': 17, 'reposts': 2}
# 保存成功
# {'id': '4404951016881817', 'text': '跟着老婆旅游可真省心啊！什么都不用操心！老婆牛逼！', 'attitudes': 4, 'comments': 2, 'reposts': 2}
# 保存成功
# {'id': '4404611089989136', 'text': '', 'attitudes': 13, 'comments': 0, 'reposts': 12}
# 保存成功
# {'id': '4404142250164586', 'text': '我在坐车的时候突然想到了一个绝妙的点子，车你赶紧开啊，我已经迫不及待要回家撸代码了！！！\n啊啊啊！！！', 'attitudes': 12, 'comments': 2, 'reposts': 0}
# 保存成功
# {'id': '4404103612232711', 'text': '和我老婆在一起之后，我胖了十六斤，今天我终于发现了胖了之后的好处。\n因为今天坐车的时候，我老婆倚在我肩膀上睡觉，老婆说：你胖了可真好啊，肩膀上都有肉了，不像之前那么咯得慌了。\n我应该哭还是笑呢。', 'attitudes': 8, 'comments': 9, 'reposts': 0}
# 保存成功
# {'id': '4404037312932821', 'text': '我老婆嘴硬，其实我一张丑照都没有，我的照片都可好看了，另外我老婆不给我照片，那我就直接转发微博了，哼！', 'attitudes': 3, 'comments': 8, 'reposts': 0}
# 保存成功
# {'id': '4403998075835932', 'text': '一开帐篷就是大草原！ 承德', 'attitudes': 6, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4403778553742590', 'text': '我老婆上次因为我没给她 P 图就发微博骂我了\n但我觉得她骂的不够狠\n哦不是不是不是\n我觉得她不用 P 就很好看 承德', 'attitudes': 12, 'comments': 10, 'reposts': 0}
# 保存成功
# {'id': '4403775999571857', 'text': '搭帐篷了！ 承德·丰宁坝上草原爱马仕度假村 崔庆才丨静觅的微博视频', 'attitudes': 7, 'comments': 1, 'reposts': 0}
# 保存成功
# {'id': '4403685859423266', 'text': '今天要和老婆出北京玩了！ 崔庆才丨静觅的微博视频', 'attitudes': 5, 'comments': 8, 'reposts': 0}
# 保存成功
# {'id': '4402934768479649', 'text': '我 jio 得可以！', 'attitudes': 2, 'comments': 0, 'reposts': 0}
# 保存成功
# {'id': '4402934551309941', 'text': '祝我杜早日康复！', 'attitudes': 0, 'comments': 0, 'reposts': 0}
# 保存成功

# %% [markdown]
# ### 今日头条街拍案例

# %%
import requests
from urllib.parse import urlencode
from pymongo import MongoClient
import time


class Toutiao(object):
    def __init__(self, name):
        self.name = name  # 获取要爬取的搜索内容相应的关键字
        self.base_url = "https://www.toutiao.com/api/search/content/?"
        self.headers = {
            "cookie":
            "tt_webid=6736143139453601287; WEATHER_CITY=%E5%8C%97%E4%BA%AC; tt_webid=6736143139453601287; csrftoken=1173d1e59061616313ba56775c3f5118; _ga=GA1.2.73970871.1568380906; s_v_web_id=9d78d95a5883b8e8a9363aa0386c9e3a",
            "referer":
            "https://www.toutiao.com/search/?keyword=%E8%A1%97%E6%8B%8D",
            "user-agent":
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36",
            "x-requested-with": "XMLHttpRequest"
        }
        # 初始化mongoDB客户端，并指定collection为 toutiao
        client = MongoClient(host='localhost', port=27017)
        db = client['TouTiao']
        self.collection = db['toutiao']

    def parse_url(self, url):
        """发送请求，获取响应"""
        print(url)
        try:
            response = requests.get(url, headers=self.headers)
            if response.status_code == 200:
                return response.json()
        except requests.ConnectionError as e:
            print("Error is ", e.args)

    def get_data(self, html_json):
        """根据传进来的json字典，提取相应的数据"""
        if html_json['count']:  # 判断新闻的数量
            items = html_json['data']  
            for item in items:
                img_dict = {}
                if item.get('has_image', None):  # 判断数据中是否含有图片
                    img_dict['title'] = item.get('title', None)  # 获取图片的title
                    img_dict['image_list'] = item.get('image_list')  # 获取所有图片的url，返回一个字典
                    yield img_dict

    def run(self):
        """实现主程序"""
        has_more = 1  # 先假设网页有多个ajax请求
        page = 0  # 初始化网页的页码
        while has_more:
            # 构造url
            self.params = {
                "aid": "24",
                "app_name": "web_search",
                "offset": page * 20,
                "format": "json",
                "keyword": self.name,
                "autoload": "true",
                "count": "20",
                "en_qc": "1",
                "cur_tab": "1",
                "from": "search_tab",
                "pd": "synthesis",
                "timestamp": int(time.time() * 1000)  # 根据ajax请求，模拟相应的时间戳
            }
            page += 1
            url = self.base_url + urlencode(self.params)
            # 发送请求获取响应
            html_json = self.parse_url(url)
            if html_json['count']:
                has_more = html_json['has_more']
            # 提取数据
            img_dict_generator = self.get_data(html_json)
            # 保存数据
            for img in img_dict_generator:
                try:
                    self.collection.insert_one(img)
                    print('保存成功')
                except:
                    print("保存过了")
            time.sleep(2)

# %%
if __name__ == "__main__":
    toutiao_jiepai = Toutiao("街拍")
    html_json = toutiao_jiepai.run()
# Out:
# https://www.toutiao.com/api/search/content/?aid=24&app_name=web_search&offset=0&format=json&keyword=%E8%A1%97%E6%8B%8D&autoload=true&count=20&en_qc=1&cur_tab=1&from=search_tab&pd=synthesis&timestamp=1569237018874
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存成功
# 保存过了
# 保存成功
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# https://www.toutiao.com/api/search/content/?aid=24&app_name=web_search&offset=20&format=json&keyword=%E8%A1%97%E6%8B%8D&autoload=true&count=20&en_qc=1&cur_tab=1&from=search_tab&pd=synthesis&timestamp=1569237021852
# 保存成功
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存成功
# 保存过了
# 保存过了
# 保存过了
# 保存成功
# 保存成功
# 保存成功
# 保存成功
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# https://www.toutiao.com/api/search/content/?aid=24&app_name=web_search&offset=40&format=json&keyword=%E8%A1%97%E6%8B%8D&autoload=true&count=20&en_qc=1&cur_tab=1&from=search_tab&pd=synthesis&timestamp=1569237024913
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存成功
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存成功
# https://www.toutiao.com/api/search/content/?aid=24&app_name=web_search&offset=60&format=json&keyword=%E8%A1%97%E6%8B%8D&autoload=true&count=20&en_qc=1&cur_tab=1&from=search_tab&pd=synthesis&timestamp=1569237027981
# 保存成功
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存成功
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# 保存过了
# https://www.toutiao.com/api/search/content/?aid=24&app_name=web_search&offset=80&format=json&keyword=%E8%A1%97%E6%8B%8D&autoload=true&count=20&en_qc=1&cur_tab=1&from=search_tab&pd=synthesis&timestamp=1569237030943
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-75032d127ea0> in <module>
#       1 if __name__ == "__main__":
#       2     toutiao_jiepai = Toutiao("街拍")
# ----> 3     html_json = toutiao_jiepai.run()
#
# <ipython-input-84-b113b59397af> in run(self)
#      67             url = self.base_url + urlencode(self.params)
#      68             # 发送请求获取响应
# ---> 69             html_json = self.parse_url(url)
#      70             if html_json['count']:
#      71                 has_more = html_json['has_more']
#
# <ipython-input-84-b113b59397af> in parse_url(self, url)
#      27         print(url)
#      28         try:
# ---> 29             response = requests.get(url, headers=self.headers)
#      30             if response.status_code == 200:
#      31                 return response.json()
#
# D:\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# D:\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# D:\anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# D:\anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# D:\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# D:\anaconda\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# D:\anaconda\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# D:\anaconda\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# D:\anaconda\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# D:\anaconda\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# D:\anaconda\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
import re
from pymongo import MongoClient
import urllib
import os
import time

def decorator(func):
    def wrap(*args, **kwargs):
        start = time.time()
        ret = func(*args, **kwargs)
        end = time.time()
        print("spend time : {:.8f}".format(end-start))
        return ret
    return wrap

def mongo_collection():
    """获取mongodb collection：toutiao  """
    client = MongoClient(host='localhost', port=27017)
    db = client['TouTiao']
    collection = db['toutiao']
    return collection

@decorator
def get_data_from_mongo(collection):
    result = collection.aggregate([{"$project":{"_id":0}}])  # 获取图片数据
    for img in result:
        title = img.get('title')
        file_name = re.sub(r'[:：，。,\.?？！!\|"”“]', "", title)  # 去掉不规范字符，防止在写入文件时因为文件名而出错
        image_list = img.get('image_list')
        for index, image in enumerate(image_list, start=1):
            src = image.get('url')
            file_path = "../crawl_file/images/toutiao/" + file_name + str(index)+".jpg"
            if not os.path.exists(file_path):  # 根据文件名判断是否文件已经下载过了
                urllib.request.urlretrieve(src, file_path)
                print('保存成功' + file_path)

        
if __name__ == "__main__":
    collection = mongo_collection()
    get_data_from_mongo(collection)
# Out:
# 保存成功../crawl_file/images/toutiao/街拍 性感美女身穿白色蕾丝内衣就敢出门路人眼都直了1.jpg
# 保存成功../crawl_file/images/toutiao/街拍 性感美女身穿白色蕾丝内衣就敢出门路人眼都直了2.jpg
# 保存成功../crawl_file/images/toutiao/街拍 性感美女身穿白色蕾丝内衣就敢出门路人眼都直了3.jpg
# 保存成功../crawl_file/images/toutiao/街拍 性感美女身穿白色蕾丝内衣就敢出门路人眼都直了4.jpg
# 保存成功../crawl_file/images/toutiao/北京街拍三里屯潮拍凸显与众不同的时尚街拍与众不同最时尚1.jpg
# 保存成功../crawl_file/images/toutiao/北京街拍三里屯潮拍凸显与众不同的时尚街拍与众不同最时尚2.jpg
# 保存成功../crawl_file/images/toutiao/北京街拍三里屯潮拍凸显与众不同的时尚街拍与众不同最时尚3.jpg
# 保存成功../crawl_file/images/toutiao/小夏街拍今天风有点大飘逸的裙摆风一样的女子3.jpg
# 保存成功../crawl_file/images/toutiao/小夏街拍今天风有点大飘逸的裙摆风一样的女子4.jpg
# 保存成功../crawl_file/images/toutiao/韩国首尔街拍合辑 ​​​​长图看看你能学到哪款搭配1.jpg
# 保存成功../crawl_file/images/toutiao/韩国首尔街拍合辑 ​​​​长图看看你能学到哪款搭配2.jpg
# 保存成功../crawl_file/images/toutiao/韩国首尔街拍合辑 ​​​​长图看看你能学到哪款搭配3.jpg
# 保存成功../crawl_file/images/toutiao/街拍看一下三里屯的小姐姐初夏时节都是怎么搭配逛街的1.jpg
# 保存成功../crawl_file/images/toutiao/路人街拍重庆街头的520街拍1.jpg
# 保存成功../crawl_file/images/toutiao/路人街拍重庆街头的520街拍2.jpg
# 保存成功../crawl_file/images/toutiao/路人街拍重庆街头的520街拍3.jpg
# 保存成功../crawl_file/images/toutiao/路人街拍重庆街头的520街拍4.jpg
# 保存成功../crawl_file/images/toutiao/街拍杭州这样的情侣就算是生气看起来都很甜啊1.jpg
# 保存成功../crawl_file/images/toutiao/伦敦千万级豪车街拍口水都流湿一地了1.jpg
# 保存成功../crawl_file/images/toutiao/成都街拍黑色背心搭配牛仔裤也能时尚潮流美1.jpg
# 保存成功../crawl_file/images/toutiao/成都街拍黑色背心搭配牛仔裤也能时尚潮流美2.jpg
# 保存成功../crawl_file/images/toutiao/成都街拍黑色背心搭配牛仔裤也能时尚潮流美3.jpg
# 保存成功../crawl_file/images/toutiao/成都街拍黑色背心搭配牛仔裤也能时尚潮流美4.jpg
# 保存成功../crawl_file/images/toutiao/路人街拍优雅多姿的小姐姐唯美的穿搭很动人尽显青春迷人气1.jpg
# 保存成功../crawl_file/images/toutiao/路人街拍优雅多姿的小姐姐唯美的穿搭很动人尽显青春迷人气2.jpg
# 保存成功../crawl_file/images/toutiao/路人街拍优雅多姿的小姐姐唯美的穿搭很动人尽显青春迷人气3.jpg
# 保存成功../crawl_file/images/toutiao/街拍街头令人难忘的背影和那些令人难忘的面孔1.jpg
# 保存成功../crawl_file/images/toutiao/街拍街头令人难忘的背影和那些令人难忘的面孔2.jpg
# 保存成功../crawl_file/images/toutiao/街拍街头令人难忘的背影和那些令人难忘的面孔3.jpg
# 保存成功../crawl_file/images/toutiao/街拍街头令人难忘的背影和那些令人难忘的面孔4.jpg
# 保存成功../crawl_file/images/toutiao/异地五年终分手不打扰是最后的温柔1.jpg
# 保存成功../crawl_file/images/toutiao/西安街拍的邻家小妹应该是所有男生都拒绝不了的吧1.jpg
# 保存成功../crawl_file/images/toutiao/西安街拍的邻家小妹应该是所有男生都拒绝不了的吧2.jpg
# 保存成功../crawl_file/images/toutiao/西安街拍的邻家小妹应该是所有男生都拒绝不了的吧3.jpg
# 保存成功../crawl_file/images/toutiao/西安街拍的邻家小妹应该是所有男生都拒绝不了的吧4.jpg
# 保存成功../crawl_file/images/toutiao/旅行能否检验情侣间的真爱那你可能要失望了1.jpg
# 保存成功../crawl_file/images/toutiao/一周男星街拍榜1.jpg
# 保存成功../crawl_file/images/toutiao/一周男星街拍榜2.jpg
# 保存成功../crawl_file/images/toutiao/一周男星街拍榜3.jpg
# 保存成功../crawl_file/images/toutiao/一周男星街拍榜4.jpg
# 保存成功../crawl_file/images/toutiao/何穗不愧是模特界的佼佼者这身材绝对美到让人望尘莫及2.jpg
# 保存成功../crawl_file/images/toutiao/何穗不愧是模特界的佼佼者这身材绝对美到让人望尘莫及3.jpg
# 保存成功../crawl_file/images/toutiao/如何更上照超模拍照的小技巧送给你1.jpg
# 保存成功../crawl_file/images/toutiao/如何更上照超模拍照的小技巧送给你2.jpg
# 保存成功../crawl_file/images/toutiao/如何更上照超模拍照的小技巧送给你3.jpg
# 保存成功../crawl_file/images/toutiao/大码健身模特身材圆润身高156体重130斤网友身材刚刚好1.jpg
# 保存成功../crawl_file/images/toutiao/大码健身模特身材圆润身高156体重130斤网友身材刚刚好2.jpg
# 保存成功../crawl_file/images/toutiao/大码健身模特身材圆润身高156体重130斤网友身材刚刚好3.jpg
# 保存成功../crawl_file/images/toutiao/维密模特讽刺大秀无聊称厌倦相同体型大秀停办或因身材歧视1.jpg
# 保存成功../crawl_file/images/toutiao/维密模特讽刺大秀无聊称厌倦相同体型大秀停办或因身材歧视2.jpg
# 保存成功../crawl_file/images/toutiao/维密模特讽刺大秀无聊称厌倦相同体型大秀停办或因身材歧视3.jpg
# 保存成功../crawl_file/images/toutiao/超模的长相有多重要除了颜值还需要有这些1.jpg
# 保存成功../crawl_file/images/toutiao/超模的长相有多重要除了颜值还需要有这些2.jpg
# 保存成功../crawl_file/images/toutiao/超模的长相有多重要除了颜值还需要有这些3.jpg
# 保存成功../crawl_file/images/toutiao/哥伦比亚健身模特腰臀比趋于完美玲珑曲线极具健康美1.jpg
# 保存成功../crawl_file/images/toutiao/哥伦比亚健身模特腰臀比趋于完美玲珑曲线极具健康美2.jpg
# 保存成功../crawl_file/images/toutiao/哥伦比亚健身模特腰臀比趋于完美玲珑曲线极具健康美3.jpg
# 保存成功../crawl_file/images/toutiao/哥伦比亚健身模特腰臀比趋于完美玲珑曲线极具健康美4.jpg
# 保存成功../crawl_file/images/toutiao/哥伦比亚健身模特腰臀比趋于完美玲珑曲线极具健康美5.jpg
# 保存成功../crawl_file/images/toutiao/对不起是我不配进时尚圈看秀的人到底是怎么忍住不笑的1.jpg
# 保存成功../crawl_file/images/toutiao/对不起是我不配进时尚圈看秀的人到底是怎么忍住不笑的2.jpg
# 保存成功../crawl_file/images/toutiao/对不起是我不配进时尚圈看秀的人到底是怎么忍住不笑的3.jpg
# 保存成功../crawl_file/images/toutiao/世界十大最性感模特（性感大图）1.jpg
# 保存成功../crawl_file/images/toutiao/世界十大最性感模特（性感大图）2.jpg
# 保存成功../crawl_file/images/toutiao/世界十大最性感模特（性感大图）3.jpg
# 保存成功../crawl_file/images/toutiao/模特美女朱瑶写真1.jpg
# 保存成功../crawl_file/images/toutiao/模特美女朱瑶写真2.jpg
# 保存成功../crawl_file/images/toutiao/模特美女朱瑶写真3.jpg
# 保存成功../crawl_file/images/toutiao/模特美女朱瑶写真4.jpg
# 保存成功../crawl_file/images/toutiao/颜值与才艺的比拼200位超模齐聚西海岸争顶东方丽人模特桂冠1.jpg
# 保存成功../crawl_file/images/toutiao/艺考招生潜规则 模特专业升学率最高的地方3.jpg
# 保存成功../crawl_file/images/toutiao/全球最美模特上帝给了她残疾却成就了她令人心碎的美貌1.jpg
# 保存成功../crawl_file/images/toutiao/全球最美模特上帝给了她残疾却成就了她令人心碎的美貌2.jpg
# 保存成功../crawl_file/images/toutiao/全球最美模特上帝给了她残疾却成就了她令人心碎的美貌3.jpg
# 保存成功../crawl_file/images/toutiao/模特民工告诉你模特的们的血泪1.jpg
# 保存成功../crawl_file/images/toutiao/模特民工告诉你模特的们的血泪2.jpg
# 保存成功../crawl_file/images/toutiao/模特民工告诉你模特的们的血泪3.jpg
# 保存成功../crawl_file/images/toutiao/模特步的基本走法1.jpg
# 保存成功../crawl_file/images/toutiao/模特步的基本走法2.jpg
# 保存成功../crawl_file/images/toutiao/模特步的基本走法3.jpg
# 保存成功../crawl_file/images/toutiao/26岁模特在T台上被鞋带绊倒猝死 观众还以为是表演1.jpg
# 保存成功../crawl_file/images/toutiao/2018世界模特大赛中国总决赛将于10月在海口举行1.jpg
# 保存成功../crawl_file/images/toutiao/2018世界模特大赛中国总决赛将于10月在海口举行2.jpg
# 保存成功../crawl_file/images/toutiao/2018世界模特大赛中国总决赛将于10月在海口举行3.jpg
# 保存成功../crawl_file/images/toutiao/模特是如何走路的只要跟着学你也能拥有超模气质1.jpg
# 保存成功../crawl_file/images/toutiao/模特是如何走路的只要跟着学你也能拥有超模气质2.jpg
# 保存成功../crawl_file/images/toutiao/模特是如何走路的只要跟着学你也能拥有超模气质3.jpg
# 保存成功../crawl_file/images/toutiao/伦敦时装周进行时模特真是怎么怪怎么穿1.jpg
# 保存成功../crawl_file/images/toutiao/伦敦时装周进行时模特真是怎么怪怎么穿2.jpg
# 保存成功../crawl_file/images/toutiao/伦敦时装周进行时模特真是怎么怪怎么穿3.jpg
# 保存成功../crawl_file/images/toutiao/伦敦时装周进行时模特真是怎么怪怎么穿4.jpg
# 保存成功../crawl_file/images/toutiao/模特公司排行榜国内知名模特经纪公司盘点1.jpg
# 保存成功../crawl_file/images/toutiao/揭秘骗子模特公司面试骗局1.jpg
# 保存成功../crawl_file/images/toutiao/东欧姑娘在杭州做电商模特一天换百套衣服三个月赚一套房1.jpg
# 保存成功../crawl_file/images/toutiao/东欧姑娘在杭州做电商模特一天换百套衣服三个月赚一套房2.jpg
# 保存成功../crawl_file/images/toutiao/东欧姑娘在杭州做电商模特一天换百套衣服三个月赚一套房3.jpg
# 保存成功../crawl_file/images/toutiao/东欧姑娘在杭州做电商模特一天换百套衣服三个月赚一套房4.jpg
# 保存成功../crawl_file/images/toutiao/模特罗茜·汉丁顿直发到墨镜气场十足身材很好大长腿吸睛1.jpg
# 保存成功../crawl_file/images/toutiao/模特罗茜·汉丁顿直发到墨镜气场十足身材很好大长腿吸睛2.jpg
# 保存成功../crawl_file/images/toutiao/模特罗茜·汉丁顿直发到墨镜气场十足身材很好大长腿吸睛3.jpg
# 保存成功../crawl_file/images/toutiao/模特罗茜·汉丁顿直发到墨镜气场十足身材很好大长腿吸睛4.jpg
# 保存成功../crawl_file/images/toutiao/模特之星大赛山东赛区总决赛落幕 男女冠军均泰安籍1.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么1.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么2.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么3.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么4.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么5.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么6.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么7.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么8.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么9.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么10.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么11.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么12.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么13.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么14.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么15.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么16.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么17.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么18.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么19.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么20.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么21.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么22.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么23.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么24.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么25.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么26.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么27.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么28.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么29.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么30.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么31.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么32.jpg
# 保存成功../crawl_file/images/toutiao/没有模特时自恋的画家们都在干什么33.jpg
# 保存成功../crawl_file/images/toutiao/中国人一辈子买不起房 乌克兰模特在中国三个月赚一套房1.jpg
# 保存成功../crawl_file/images/toutiao/中国人一辈子买不起房 乌克兰模特在中国三个月赚一套房2.jpg
# 保存成功../crawl_file/images/toutiao/中国人一辈子买不起房 乌克兰模特在中国三个月赚一套房3.jpg
# 保存成功../crawl_file/images/toutiao/每日说名画身患残疾的少女却成为艺术史上著名的模特1.jpg
# 保存成功../crawl_file/images/toutiao/每日说名画身患残疾的少女却成为艺术史上著名的模特2.jpg
# 保存成功../crawl_file/images/toutiao/每日说名画身患残疾的少女却成为艺术史上著名的模特3.jpg
# 保存成功../crawl_file/images/toutiao/每日说名画身患残疾的少女却成为艺术史上著名的模特4.jpg
# 保存成功../crawl_file/images/toutiao/这可能是我见过最美的模特了画家绘制的感觉非常棒1.jpg
# 保存成功../crawl_file/images/toutiao/这可能是我见过最美的模特了画家绘制的感觉非常棒2.jpg
# 保存成功../crawl_file/images/toutiao/这可能是我见过最美的模特了画家绘制的感觉非常棒3.jpg
# 保存成功../crawl_file/images/toutiao/这可能是我见过最美的模特了画家绘制的感觉非常棒4.jpg
# 保存成功../crawl_file/images/toutiao/美国第一夫人出生贫苦为谋生当模特宴会多次拒绝川普成佳话1.jpg
# 保存成功../crawl_file/images/toutiao/美国第一夫人出生贫苦为谋生当模特宴会多次拒绝川普成佳话2.jpg
# 保存成功../crawl_file/images/toutiao/美国第一夫人出生贫苦为谋生当模特宴会多次拒绝川普成佳话3.jpg
# 保存成功../crawl_file/images/toutiao/女友做模特天天被画家描来描去我难以接受1.jpg
# 保存成功../crawl_file/images/toutiao/模特随意拍照网友表示很美很养眼1.jpg
# 保存成功../crawl_file/images/toutiao/模特随意拍照网友表示很美很养眼2.jpg
# 保存成功../crawl_file/images/toutiao/模特随意拍照网友表示很美很养眼3.jpg
# 保存成功../crawl_file/images/toutiao/模特随意拍照网友表示很美很养眼4.jpg
# 保存成功../crawl_file/images/toutiao/国庆一起出去玩吧1.jpg
# 保存成功../crawl_file/images/toutiao/国际模特大赛总决赛彩排选手风采1.jpg
# 保存成功../crawl_file/images/toutiao/国际模特大赛总决赛彩排选手风采2.jpg
# 保存成功../crawl_file/images/toutiao/国际模特大赛总决赛彩排选手风采3.jpg
# 保存成功../crawl_file/images/toutiao/维密秀来了是什么让你对维密秀欲罢不能带你看维密的中国化1.jpg
# 保存成功../crawl_file/images/toutiao/维密秀来了是什么让你对维密秀欲罢不能带你看维密的中国化2.jpg
# 保存成功../crawl_file/images/toutiao/维密秀来了是什么让你对维密秀欲罢不能带你看维密的中国化3.jpg
# 保存成功../crawl_file/images/toutiao/2017年度吸金模特1.jpg
# 保存成功../crawl_file/images/toutiao/性感模特1.jpg
# 保存成功../crawl_file/images/toutiao/美国姐妹花模特合体现身炫腹又秀腿街头变T台画面养眼1.jpg
# 保存成功../crawl_file/images/toutiao/美国姐妹花模特合体现身炫腹又秀腿街头变T台画面养眼2.jpg
# 保存成功../crawl_file/images/toutiao/美国姐妹花模特合体现身炫腹又秀腿街头变T台画面养眼3.jpg
# 保存成功../crawl_file/images/toutiao/美国姐妹花模特合体现身炫腹又秀腿街头变T台画面养眼4.jpg
# 保存成功../crawl_file/images/toutiao/2018中泰杯顶峰精英模特大赛决赛圆满落幕1.jpg
# 保存成功../crawl_file/images/toutiao/3分钟看我伊藤润二惊选集之恐怖模特1.jpg
# 保存成功../crawl_file/images/toutiao/三分钟看完 2018北京车展 所有漂亮模特礼仪 酷车 概念车都在了1.jpg
# 保存成功../crawl_file/images/toutiao/美呆了看见模特小姐姐我仿佛恋爱了1.jpg
# 保存成功../crawl_file/images/toutiao/美呆了看见模特小姐姐我仿佛恋爱了2.jpg
# 保存成功../crawl_file/images/toutiao/美呆了看见模特小姐姐我仿佛恋爱了3.jpg
# 保存成功../crawl_file/images/toutiao/2018VILA RESOR时装新品发布会模特走秀超清1.jpg
# 保存成功../crawl_file/images/toutiao/年龄阻挡不了的美丽和气质70岁的模特惊艳T台1.jpg
# 保存成功../crawl_file/images/toutiao/年龄阻挡不了的美丽和气质70岁的模特惊艳T台2.jpg
# 保存成功../crawl_file/images/toutiao/年龄阻挡不了的美丽和气质70岁的模特惊艳T台3.jpg
# 保存成功../crawl_file/images/toutiao/年龄阻挡不了的美丽和气质70岁的模特惊艳T台4.jpg
# 保存成功../crawl_file/images/toutiao/满屏大长腿2018精功模特海南赛区决赛冠军出炉1.jpg
# 保存成功../crawl_file/images/toutiao/满屏大长腿2018精功模特海南赛区决赛冠军出炉2.jpg
# 保存成功../crawl_file/images/toutiao/满屏大长腿2018精功模特海南赛区决赛冠军出炉3.jpg
# 保存成功../crawl_file/images/toutiao/满屏大长腿2018精功模特海南赛区决赛冠军出炉4.jpg
# 保存成功../crawl_file/images/toutiao/满屏大长腿2018精功模特海南赛区决赛冠军出炉5.jpg
# 保存成功../crawl_file/images/toutiao/满屏大长腿2018精功模特海南赛区决赛冠军出炉6.jpg
# 保存成功../crawl_file/images/toutiao/满屏大长腿2018精功模特海南赛区决赛冠军出炉7.jpg
# 保存成功../crawl_file/images/toutiao/满屏大长腿2018精功模特海南赛区决赛冠军出炉8.jpg
# 保存成功../crawl_file/images/toutiao/满屏大长腿2018精功模特海南赛区决赛冠军出炉9.jpg
# 保存成功../crawl_file/images/toutiao/满屏大长腿2018精功模特海南赛区决赛冠军出炉10.jpg
# 保存成功../crawl_file/images/toutiao/后台疲惫不堪的女模特们1.jpg
# 保存成功../crawl_file/images/toutiao/后台疲惫不堪的女模特们2.jpg
# 保存成功../crawl_file/images/toutiao/后台疲惫不堪的女模特们3.jpg
# 保存成功../crawl_file/images/toutiao/后台疲惫不堪的女模特们4.jpg
# 保存成功../crawl_file/images/toutiao/姚晨一家四口郊游女儿穿T恤光腿在溪边玩耍大儿子长相太像爸2.jpg
# 保存成功../crawl_file/images/toutiao/姚晨一家四口郊游女儿穿T恤光腿在溪边玩耍大儿子长相太像爸3.jpg
# 保存成功../crawl_file/images/toutiao/姚晨一家四口郊游女儿穿T恤光腿在溪边玩耍大儿子长相太像爸4.jpg
# 保存成功../crawl_file/images/toutiao/姚晨一家四口郊游女儿穿T恤光腿在溪边玩耍大儿子长相太像爸5.jpg
# 保存成功../crawl_file/images/toutiao/姚晨一家四口郊游女儿穿T恤光腿在溪边玩耍大儿子长相太像爸6.jpg
# 保存成功../crawl_file/images/toutiao/姚晨一家四口郊游女儿穿T恤光腿在溪边玩耍大儿子长相太像爸7.jpg
# 保存成功../crawl_file/images/toutiao/金卡戴珊与妹妹肯豆同框肯豆超模范儿十足金大姐3D身材更吸睛1.jpg
# 保存成功../crawl_file/images/toutiao/金卡戴珊与妹妹肯豆同框肯豆超模范儿十足金大姐3D身材更吸睛2.jpg
# 保存成功../crawl_file/images/toutiao/金卡戴珊与妹妹肯豆同框肯豆超模范儿十足金大姐3D身材更吸睛3.jpg
# 保存成功../crawl_file/images/toutiao/现在女生衣着暴露小姐姐的回答让人哑口无言1.jpg
# 保存成功../crawl_file/images/toutiao/街拍一波美女哪一个最养眼1.jpg
# 保存成功../crawl_file/images/toutiao/看完倪妮、刘雯的街拍才知道我的照片为什么会这么土1.jpg
# 保存成功../crawl_file/images/toutiao/长安CS75PLUS火了周末完成万人交车1.jpg
# 保存成功../crawl_file/images/toutiao/长安CS75PLUS火了周末完成万人交车2.jpg
# 保存成功../crawl_file/images/toutiao/长安CS75PLUS火了周末完成万人交车3.jpg
# 保存成功../crawl_file/images/toutiao/190923 邓·行走的画报·伦街拍公开 收割今日份小心心1.jpg
# 保存成功../crawl_file/images/toutiao/190923 邓·行走的画报·伦街拍公开 收割今日份小心心2.jpg
# 保存成功../crawl_file/images/toutiao/190923 邓·行走的画报·伦街拍公开 收割今日份小心心3.jpg
# 保存成功../crawl_file/images/toutiao/190923 邓·行走的画报·伦街拍公开 收割今日份小心心4.jpg
# 保存成功../crawl_file/images/toutiao/190923 邓·行走的画报·伦街拍公开 收割今日份小心心5.jpg
# 保存成功../crawl_file/images/toutiao/190923 邓·行走的画报·伦街拍公开 收割今日份小心心6.jpg
# 保存成功../crawl_file/images/toutiao/190923 邓·行走的画报·伦街拍公开 收割今日份小心心7.jpg
# 保存成功../crawl_file/images/toutiao/190923 邓·行走的画报·伦街拍公开 收割今日份小心心8.jpg
# 保存成功../crawl_file/images/toutiao/190923 邓·行走的画报·伦街拍公开 收割今日份小心心9.jpg
# 保存成功../crawl_file/images/toutiao/街拍不仅穿着舒适更显高还恰到妙处呈现女人魅力1.jpg
# 保存成功../crawl_file/images/toutiao/街拍不仅穿着舒适更显高还恰到妙处呈现女人魅力2.jpg
# 保存成功../crawl_file/images/toutiao/街拍不仅穿着舒适更显高还恰到妙处呈现女人魅力3.jpg
# spend time : 133.85720873
