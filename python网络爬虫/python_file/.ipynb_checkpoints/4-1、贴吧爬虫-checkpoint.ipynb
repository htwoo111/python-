# %%
from requests import RequestException
import requests
import json
from lxml import etree
import time



class Tieba(object):

    def __init__(self, name):
        self.name = name
        self.url_temp = "http://c.tieba.baidu.com/f?ie=utf-8&kw=" +\
                        requests.utils.quote(self.name) +\
                        "&fr=search&pn={}"
        self.headers = {
            "Cookie": "BAIDUID=433DB4AAED0290A1196E65E26551F041:FG=1; BIDUPSID=433DB4AAED0290A1196E65E26551F041; PSTM=1560467964; BDUSS=dnfn5zZnE3eHNlMkMwdjlLR3dUVH56WDR1OHhVQWY1UTBZZjFrSUhhMm9WM3RkRVFBQUFBJCQAAAAAAAAAAAEAAADTpYnPaHR3b28yMjIAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAKjKU12oylNdVT; TIEBAUID=8def7439658107cd1106f38b; STOKEN=ffce0822077b028660923867c7aec6d035e7a63adf151b67759a76671085058f; TIEBA_USERTYPE=744b29c1d10868fb821f4b1b; locale=zh; IS_NEW_USER=13f77af84c1af1678ec28563; BAIDU_WISE_UID=wapp_1568616371161_183; H_WISE_SIDS=134725_124610_132921_100805_135964_136285_128065_135948_120155_132909_131247_132378_131518_118882_118865_118855_118830_118798_107312_133352_129655_136193_132250_127025_128967_135307_135813_132551_133287_135432_135874_129643_131423_134600_136019_135592_110085_136144_127969_131754_131951_135672_135458_127417_135870_135036_134383_134353_135834_136259_136077; BDRCVFR[feWj1Vr5u3D]=I67x6TjHwwYf0; delPer=0; PSINO=7; BDORZ=B490B5EBF6F3CD402E515D22BCDA1598; H_PS_PSSID=29654_1423_21087_29523_29521_29720_29567_29220_26350_22158; 3481904595_FRSVideoUploadTip=1; USER_JUMP=-1; CLIENTWIDTH=414; CLIENTHEIGHT=736; LASW=414; SEENKW=%E6%9D%8E%E6%AF%85%23%C0%EE%D2%E3; Hm_lvt_98b9d8c2fd6608d564bf2ac2ae642948=1568764717,1568765525,1568765532,1568765535; mo_originid=2; Hm_lpvt_98b9d8c2fd6608d564bf2ac2ae642948=1568765836",
            "User-Agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like Mac OS X) AppleWebKit/604.1.38 (KHTML, like Gecko) Version/11.0 Mobile/15A372 Safari/604.1"
        }
        
    def parse_url(self, url):
        """解析url，获取html"""
        try:
            print(url)
            r = requests.get(url, headers=self.headers)
            if r.status_code == 200:
                print('获取到网页')
                return r.text
            return None
        except RequestException:
            print('请求失败')
            return None
        except Exception as e:
            print("Error is " + e)
            return None
    
    def get_content_list(self, html_str):
        """提取数据"""
        html = etree.HTML(html_str)
        li_list = html.xpath('//ul[@id="frslistcontent"]/li[@class="tl_shadow tl_shadow_new "]')
        content_list = []
        for li in li_list:
            item = {}
            item['author'] = li.xpath('./div//span[@class="ti_author"]/text()')[0].strip() if len(li.xpath('./div//span[@class="ti_author"]/text()'))>0 else None
            item['title'] = li.xpath('./a//div[@class="ti_title"]/span[last()]/text()') if len(li.xpath('./a//div[@class="ti_title"]/span[last()]'))>0 else None
            item['href'] = "http://c.tieba.baidu.com" + li.xpath('./a[@class="j_common ti_item "]/@href')[0] if len(li.xpath('./a[@class="j_common ti_item "]/@href'))>0 else None
            content_list.append(item)
        return content_list

    def save_data(self, content_list):
        file_path = "../crawl_file/贴吧爬虫-" + self.name  + ".txt"
        with open(file_path, "a+", encoding='utf-8') as f:
            for content in content_list:
                f.write(json.dumps(content, ensure_ascii=False))
                f.write('\n')
        print('保存成功')
        
        
    def run(self):
        pn = 0
        while True:
            # 1.构造url
            url = self.url_temp.format(pn)
            # 2.发送请求，获取html
            html_str = self.parse_url(url)
            # 3.提取数据
            content_list = self.get_content_list(html_str)
            # 4.保存数据
            self.save_data(content_list)
            # 设置退出条件
            if pn > 3000:
                break
            # 5.构造下一个url,进入循环1-4
            pn += 30
            # 设置sleep，防止被反爬
            time.sleep(2)

# %%
if __name__ == "__main__":
    tieba = Tieba('LOL')
    html_str = tieba.run()

# %%
from requests import RequestException
import requests
import json
from lxml import etree
import time



class Tieba2(object):

    def __init__(self, name):
        self.name = name
        self.url_temp = "http://c.tieba.baidu.com/f?ie=utf-8&kw=" +\
                        requests.utils.quote(self.name) +\
                        "&fr=search&pn={}"
        self.headers = {
            "Cookie": "BAIDUID=433DB4AAED0290A1196E65E26551F041:FG=1; BIDUPSID=433DB4AAED0290A1196E65E26551F041; PSTM=1560467964; BDUSS=dnfn5zZnE3eHNlMkMwdjlLR3dUVH56WDR1OHhVQWY1UTBZZjFrSUhhMm9WM3RkRVFBQUFBJCQAAAAAAAAAAAEAAADTpYnPaHR3b28yMjIAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAKjKU12oylNdVT; TIEBAUID=8def7439658107cd1106f38b; STOKEN=ffce0822077b028660923867c7aec6d035e7a63adf151b67759a76671085058f; TIEBA_USERTYPE=744b29c1d10868fb821f4b1b; locale=zh; IS_NEW_USER=13f77af84c1af1678ec28563; BAIDU_WISE_UID=wapp_1568616371161_183; H_WISE_SIDS=134725_124610_132921_100805_135964_136285_128065_135948_120155_132909_131247_132378_131518_118882_118865_118855_118830_118798_107312_133352_129655_136193_132250_127025_128967_135307_135813_132551_133287_135432_135874_129643_131423_134600_136019_135592_110085_136144_127969_131754_131951_135672_135458_127417_135870_135036_134383_134353_135834_136259_136077; BDRCVFR[feWj1Vr5u3D]=I67x6TjHwwYf0; delPer=0; PSINO=7; BDORZ=B490B5EBF6F3CD402E515D22BCDA1598; H_PS_PSSID=29654_1423_21087_29523_29521_29720_29567_29220_26350_22158; 3481904595_FRSVideoUploadTip=1; USER_JUMP=-1; CLIENTWIDTH=414; CLIENTHEIGHT=736; LASW=414; SEENKW=%E6%9D%8E%E6%AF%85%23%C0%EE%D2%E3; Hm_lvt_98b9d8c2fd6608d564bf2ac2ae642948=1568764717,1568765525,1568765532,1568765535; mo_originid=2; Hm_lpvt_98b9d8c2fd6608d564bf2ac2ae642948=1568765836",
            "User-Agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 11_0 like Mac OS X) AppleWebKit/604.1.38 (KHTML, like Gecko) Version/11.0 Mobile/15A372 Safari/604.1"
        }
        
    def parse_url(self, url):
        """解析url，获取html"""
        try:
            print(url)
            r = requests.get(url, headers=self.headers)
            if r.status_code == 200:
                print('获取到网页')
                return r.text
            return None
        except RequestException:
            print('请求失败')
            return None
        except Exception as e:
            print("Error is " + e)
            return None
    
    def get_content_list(self, html_str):
        """提取数据"""
        html = etree.HTML(html_str)
        li_list = html.xpath('//ul[@id="frslistcontent"]/li[@class="tl_shadow tl_shadow_new "]')
        content_list = []
        for li in li_list:
            item = {}
            item['author'] = li.xpath('./div//span[@class="ti_author"]/text()')[0].strip() if len(li.xpath('./div//span[@class="ti_author"]/text()'))>0 else None
            item['title'] = li.xpath('./a//div[@class="ti_title"]/span[last()]/text()') if len(li.xpath('./a//div[@class="ti_title"]/span[last()]'))>0 else None
            item['href'] = "http://c.tieba.baidu.com" + li.xpath('./a[@class="j_common ti_item "]/@href')[0] if len(li.xpath('./a[@class="j_common ti_item "]/@href'))>0 else None
            item['imgs'] = self.get_imgs(item['href'])
            content_list.append(item)
        return content_list

    def get_imgs(self, href):
#         print(href)
        detail_html_str = self.parse_url(href)
        html = etree.HTML(detail_html_str)
#         print(etree.tostring(html))
        imgs_list = html.xpath('//div[@id="pb_imgs_div"]//img/@src')
        if len(imgs_list)>0:
            print("-----------")
            print(imgs_list)
            print('-----------')
            return imgs_list
        
        return None
    
    
    def save_data(self, content_list):
        file_path = "../crawl_file/贴吧爬虫-" + self.name  + ".txt"
        with open(file_path, "a+", encoding='utf-8') as f:
            for content in content_list:
                f.write(json.dumps(content, ensure_ascii=False))
                f.write('\n')
        print('保存成功')
        
        
    def run(self):
        pn = 0
        while True:
            # 1.构造url
            url = self.url_temp.format(pn)
            # 2.发送请求，获取html
            html_str = self.parse_url(url)
            # 3.提取数据
            content_list = self.get_content_list(html_str)
            # 4.保存数据
            self.save_data(content_list)
            # 设置退出条件
            if pn > 3000:
                break
            # 5.构造下一个url,进入循环1-4
            pn += 30
            # 设置sleep，防止被反爬
            time.sleep(2)

# %%
if __name__ == "__main__":
    tieba = Tieba2('LOL')
    html_str = tieba.run()
# Out:
# http://c.tieba.baidu.com/f?ie=utf-8&kw=LOL&fr=search&pn=0
# 获取到网页
# http://c.tieba.baidu.com/p/6251677422?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6253679724?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259772932?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6257016014?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259897302?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6256733885?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6253279023?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6250359140?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6225763071?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259057892?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259162126?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# -----------
# ['//tb2.bdstatic.com/tb/mobile/spb/widget/pb_imgs/img/pic_icon_3a89491.png']
# -----------
# http://c.tieba.baidu.com/p/6259243657?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6251203137?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# -----------
# ['//tb2.bdstatic.com/tb/mobile/spb/widget/pb_imgs/img/pic_icon_3a89491.png']
# -----------
# http://c.tieba.baidu.com/p/6259261403?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6241756019?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6246462174?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6257194401?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259148116?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259854132?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259681133?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259454867?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6253408172?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6256321188?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259696531?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6256825780?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6258241695?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259455790?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6024460994?lp=5028&mo_device=1&is_jingpost=0
# 获取到网页
# 保存成功
# http://c.tieba.baidu.com/f?ie=utf-8&kw=LOL&fr=search&pn=30
# 获取到网页
# http://c.tieba.baidu.com/p/6258241695?lp=5027&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259455790?lp=5027&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6024460994?lp=5027&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259870551?lp=5027&mo_device=1&is_jingpost=0
# 获取到网页
# -----------
# ['//tb2.bdstatic.com/tb/mobile/spb/widget/pb_imgs/img/pic_icon_3a89491.png']
# -----------
# http://c.tieba.baidu.com/p/6257948488?lp=5027&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259456224?lp=5027&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259897670?lp=5027&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259698806?lp=5027&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259454413?lp=5027&mo_device=1&is_jingpost=0
# 获取到网页
# http://c.tieba.baidu.com/p/6259362914?lp=5027&mo_device=1&is_jingpost=0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-6330ee0b2ec0> in <module>
#       1 if __name__ == "__main__":
#       2     tieba = Tieba2('LOL')
# ----> 3     html_str = tieba.run()
#
# <ipython-input-31-e52dedf6cb46> in run(self)
#      81             html_str = self.parse_url(url)
#      82             # 3.提取数据
# ---> 83             content_list = self.get_content_list(html_str)
#      84             # 4.保存数据
#      85             self.save_data(content_list)
#
# <ipython-input-31-e52dedf6cb46> in get_content_list(self, html_str)
#      45             item['title'] = li.xpath('./a//div[@class="ti_title"]/span[last()]/text()') if len(li.xpath('./a//div[@class="ti_title"]/span[last()]'))>0 else None
#      46             item['href'] = "http://c.tieba.baidu.com" + li.xpath('./a[@class="j_common ti_item "]/@href')[0] if len(li.xpath('./a[@class="j_common ti_item "]/@href'))>0 else None
# ---> 47             item['imgs'] = self.get_imgs(item['href'])
#      48             content_list.append(item)
#      49         return content_list
#
# <ipython-input-31-e52dedf6cb46> in get_imgs(self, href)
#      51     def get_imgs(self, href):
#      52 #         print(href)
# ---> 53         detail_html_str = self.parse_url(href)
#      54         html = etree.HTML(detail_html_str)
#      55 #         print(etree.tostring(html))
#
# <ipython-input-31-e52dedf6cb46> in parse_url(self, url)
#      23         try:
#      24             print(url)
# ---> 25             r = requests.get(url, headers=self.headers)
#      26             if r.status_code == 200:
#      27                 print('获取到网页')
#
# D:\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# D:\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# D:\anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# D:\anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# D:\anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# D:\anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     352             conn.request_chunked(method, url, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#     356         # Reset the timeout for the recv() on the socket
#
# D:\anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1227                 encode_chunked=False):
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#    1231     def _send_request(self, method, url, body, headers, encode_chunked):
#
# D:\anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1273             # default charset of iso-8859-1.
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#    1277     def getresponse(self):
#
# D:\anaconda\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1222         else:
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#    1226     def request(self, method, url, body=None, headers={}, *,
#
# D:\anaconda\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1014         msg = b"\r\n".join(self._buffer)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#    1018         if message_body is not None:
#
# D:\anaconda\lib\http\client.py in send(self, data)
#     954         if self.sock is None:
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#     958                 raise NotConnected()
#
# D:\anaconda\lib\site-packages\urllib3\connection.py in connect(self)
#     179
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#     183
#
# D:\anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# D:\anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:
